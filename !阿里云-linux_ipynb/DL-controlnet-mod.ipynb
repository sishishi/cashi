# %%
def aria2(url, filename, d):
    # !aria2c --console-log-level=error -c -x 16 -s 16 {url} -o {filename} -d {d}

model_urls = """
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_shuffle.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1e_sd15_tile.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_mlsd.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_scribble.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth
  https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15s2_lineart_anime.pth
"""

models = model_urls.strip().split("\n")

for e in models:
    aria2(e, e.split("/")[-1], "/mnt/workspace/stable-diffusion-webui/models/ControlNet")
# Out:
# 07/13 06:47:08 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11e_sd15_ip2p.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 76f537|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11e_sd15_ip2p.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# [#2fdae1 0B/0B CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2fdae1|OK  |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11e_sd15_shuffle.pth
#
# Status Legend:
# (OK):download completed.
# [#25b8f5 0B/0B CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 25b8f5|OK  |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11f1e_sd15_tile.pth
#
# Status Legend:
# (OK):download completed.
#
# 07/13 06:47:11 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11f1p_sd15_depth.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://cdn-lfs.huggingface.co/repos/e7/4c/e74c9ddc88b5a293fa8aafeb615d6c61cb3aaa34dc7ce9e25100dfae2b09bf55/761077ffe369fe8cf16ae353f8226bd4ca29805b161052f82c0170c7b50f1d99?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27control_v11f1p_sd15_depth.pth%3B+filename%3D%22control_v11f1p_sd15_depth.pth%22%3B&Expires=1689490031&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=Kv2cRVekBIRlyaK1IvnpJ8jRcKTUkJPq3I7O%7EsUtJhoB6FgLfOXyU5fhtHMuXMKSFMyUhkwa2zHXp7CRtDgggV9UeDWDA1OlHLHPpckaliQbZmBTuHDvtNOHbObQu4e3bLV%7EJxq%7EnaJzlIJ-CBMDz3RJl74sbqP5YFZ%7EIzvB8OqivWDG4QLnWICfCOajX75Csz1YblwrBqYlJNuQaHYK1WWZtKr%7Ezk1NJ8fkHn7npmj3zKOumjz5DpOfuo4eKTiz2zS805JuxlwKgpAjbElcBRoHjwp3vs8-x53G0Any8bKD7O%7ELrIbtRCqRMyWbHGjdpdSA8it6v-GIMO7HhqGALg__&Key-Pair-Id=KVTP0A1DKRTAX
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a275d3|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11f1p_sd15_depth.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:47:12 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_canny.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://cdn-lfs.huggingface.co/repos/e7/4c/e74c9ddc88b5a293fa8aafeb615d6c61cb3aaa34dc7ce9e25100dfae2b09bf55/f99cfe4c70910e38e3fece9918a4979ed7d3dcf9b81cee293e1755363af5406a?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27control_v11p_sd15_canny.pth%3B+filename%3D%22control_v11p_sd15_canny.pth%22%3B&Expires=1689490032&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=tsuQj8zUgT2ikgYZRrIVC9f9jwI4mDfTEusu%7ET6gP5l-vEFgSsybOadCnm2ekekbkCe9cm7VRhF5QtlojoyVSl2mvqvsuRUFYDg3A2DA%7El9l2v8i1HT6BTeuGlEt0-WVuFKx0y%7EXfD7pZnh4eIi4QnleZsmsEgVihfRVe6ZQpjBGPbbcV3u%7EUMdR2qSspMyEPCy8jKLsK4LQIVpPq3X9Jb1mlMCIjJ1UMSwlK4aMKNVTY4Gq2M68uoXnukV%7EWVxalsiBIzeo4636qvPE5faFSWa2-VWB8vN05mc-f4z4FEeATMK-vxo73TTEGeEi4qRAC2UC0a3dDO-HubAJilI-iQ__&Key-Pair-Id=KVTP0A1DKRTAX
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 10a7f1|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_canny.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:47:13 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_inpaint.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 4c1c42|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_inpaint.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:47:13 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_lineart.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a211f1|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_lineart.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# [#f44494 0B/0B CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f44494|OK  |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_mlsd.pth
#
# Status Legend:
# (OK):download completed.
# [#93f80a 0B/0B CN:1 DL:0B]
# 07/13 06:47:16 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_normalbae.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://cdn-lfs.huggingface.co/repos/e7/4c/e74c9ddc88b5a293fa8aafeb615d6c61cb3aaa34dc7ce9e25100dfae2b09bf55/9608158c204261259f4b5a7815ced8f5c15e5de4e30a9403d07f68f29f81e941?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27control_v11p_sd15_normalbae.pth%3B+filename%3D%22control_v11p_sd15_normalbae.pth%22%3B&Expires=1689488953&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=ZSKgyjwGbaVbvlHL1qzZ8A1hEnBib8KJ0jL5Zc-AfN7Vi154y-gkOeS8Siy-erwMlaapp-JXzNrk6%7EZIKv5uCtimCTK4ZFcINH1oYpIIDrizzt9U%7ElbL01D840TBsjMHWfS2AGffpo0e6Cmdb%7EDJsqRZLzf2hBm3TxeGb%7EhattW7G%7EvlsA8HgUlFbmLrYnQ8pDwvdXQw4caEVB-%7ELuDbH8KWiLTz9SmcD3gpEVXM%7E%7EBOsMIpae-X23YGTHw5gD6Sd-QmP4kd2rmtc2CqaF4XqryGe8F5%7E7K6JhmQTLOgQJaK577LIdQC4326IAbT%7E2LF5U2%7Eefh6Sw%7ENb51%7EoV87DA__&Key-Pair-Id=KVTP0A1DKRTAX
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 93f80a|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_normalbae.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:47:16 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_openpose.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 35698d|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_openpose.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# [#8b0a36 0B/0B CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8b0a36|OK  |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_scribble.pth
#
# Status Legend:
# (OK):download completed.
#
# 07/13 06:47:18 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_seg.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 494803|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_seg.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:47:18 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/ControlNet-v1-1/resolve/main/control_v11p_sd15_softedge.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f53acb|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15_softedge.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# [#17a92e 0B/0B CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 17a92e|OK  |       0B/s|/mnt/workspace/stable-diffusion-webui/models/ControlNet/control_v11p_sd15s2_lineart_anime.pth
#
# Status Legend:
# (OK):download completed.
