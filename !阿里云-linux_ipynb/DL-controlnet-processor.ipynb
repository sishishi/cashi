# %%
def aria2(url, filename, d):
    # !aria2c --console-log-level=error -c -x 16 -s 16 {url} -o {filename} -d {d}

model_urls = """
  https://huggingface.co/lllyasviel/Annotators/resolve/main/res101.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/sk_model2.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/sk_model.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/dpt_hybrid-midas-501f0c75.pt
  https://huggingface.co/lllyasviel/Annotators/resolve/main/mlsd_large_512_fp32.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/scannet.pt
  https://huggingface.co/lllyasviel/Annotators/resolve/main/250_16_swin_l_oneformer_ade20k_160k.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/150_16_swin_l_oneformer_coco_100ep.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/body_pose_model.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/facenet.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/hand_pose_model.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/table5_pidinet.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/upernet_global_small.pth
  https://huggingface.co/lllyasviel/Annotators/resolve/main/ZoeD_M12_N.pt
"""

models = model_urls.strip().split("\n")

for e in models:
    aria2(e, e.split("/")[-1], "/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads")
# Out:
# 07/13 06:22:32 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/res101.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/res101.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f95b62|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/res101.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# [#a58978 0B/0B CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a58978|OK  |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/sk_model2.pth
#
# Status Legend:
# (OK):download completed.
#
# 07/13 06:22:34 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/sk_model.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/sk_model.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 792603|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/sk_model.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:22:34 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/dpt_hybrid-midas-501f0c75.pt
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/dpt_hybrid-midas-501f0c75.pt
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a7ed07|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/dpt_hybrid-midas-501f0c75.pt
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:22:35 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/mlsd_large_512_fp32.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/mlsd_large_512_fp32.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 061e04|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/mlsd_large_512_fp32.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:22:35 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/scannet.pt
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/scannet.pt
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 6c15a1|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/scannet.pt
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:22:36 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/250_16_swin_l_oneformer_ade20k_160k.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/250_16_swin_l_oneformer_ade20k_160k.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 55d1ce|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/250_16_swin_l_oneformer_ade20k_160k.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:22:36 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/150_16_swin_l_oneformer_coco_100ep.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/150_16_swin_l_oneformer_coco_100ep.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 1a1a60|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/150_16_swin_l_oneformer_coco_100ep.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:22:36 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/body_pose_model.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/body_pose_model.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3c2c93|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/body_pose_model.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
#
# 07/13 06:22:37 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/facenet.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/facenet.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a63079|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/facenet.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# [#a9b91e 0B/0B CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a9b91e|OK  |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/hand_pose_model.pth
#
# Status Legend:
# (OK):download completed.
#
# 07/13 06:22:38 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/table5_pidinet.pth
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/table5_pidinet.pth
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 145aa3|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/table5_pidinet.pth
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
# [#72a2f8 0B/0B CN:1 DL:0B]
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 72a2f8|OK  |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/upernet_global_small.pth
#
# Status Legend:
# (OK):download completed.
#
# 07/13 06:22:40 [ERROR] CUID#7 - Download aborted. URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/ZoeD_M12_N.pt
# Exception: [AbstractCommand.cc:351] errorCode=1 URI=https://huggingface.co/lllyasviel/Annotators/resolve/main/ZoeD_M12_N.pt
#   -> [SocketCore.cc:1018] errorCode=1 SSL/TLS handshake failure: Error in the pull function.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# c0acd0|ERR |       0B/s|/mnt/workspace/stable-diffusion-webui/extensions/sd-webui-controlnet/annotator/downloads/ZoeD_M12_N.pt
#
# Status Legend:
# (ERR):error occurred.
#
# aria2 will resume download if the transfer is restarted.
# If there are any errors, then see the log file. See '-l' option in help/man page for details.
